# %% [markdown]
# # Temperature
#
# Requirements:
# - Use preferrably Python 3.9.6 venvs.
# - Add a `.env` file in the same folder as this notebook with an `ANTHROPIC_API_KEY="<api_key_here>"` field.

# %% [markdown]
# ## 1 Making a request
# - API
# - Auth

# %% [markdown]
# ## 2 Functions
# - Helpers

# %%
# Helper functions

def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

# New chat function

def chat(
    messages,
    system=None,
):
    # Required
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }
    
    # Optional
    if system:
        params["system"] = system
    
    # KW-args
    message = client.messages.create(**params)
    return message.content[0].text

# %% [markdown]
# ## 3 Temperature
# - Chat func with optional `temperature`

# %%
# New chat function

def chat(
    messages,
    system=None,
    temperature=1.0,
):
    # Required
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
    }
    
    # Optional
    if system:
        params["system"] = system
    
    # KW-args
    message = client.messages.create(**params)
    return message.content[0].text

# %%
user_prompt = "Write a movie script."

# %%
# Low temperature - more predictable
messages = []
add_user_message(messages, user_prompt)

answer = chat(messages, temperature=0.0)
print("Low temperature answer:", answer, sep="\n")
# Out:
# Low temperature answer:
# # ECHOES IN THE DARK
#
# ### An Original Screenplay
#
# ---
#
# FADE IN:
#
# ---
#
# ## ACT ONE
#
# ---
#
# **EXT. RURAL HIGHWAY - NIGHT**
#
# A two-lane road cuts through dense pine forest. No streetlights. No signs of civilization. Just darkness and the occasional flash of lightning on the horizon.
#
# A pair of headlights appears in the distance, moving fast.
#
# **INT. CAR - CONTINUOUS**
#
# MAYA CHEN (32, sharp eyes, exhausted, still wearing hospital scrubs under an unzipped jacket) grips the steering wheel. A half-empty coffee cup sits in the holder. Her phone is mounted on the dash — the GPS signal keeps cutting in and out.
#
# A duffel bag sits on the passenger seat. She glances at it. Looks away.
#
# **GPS (V.O.)**
# *(robotic, glitching)*
# Recalculating... recalculating...
#
# Maya exhales sharply. Taps the screen. Nothing.
#
# She reaches into the duffel bag without looking and pulls out a folded paper map — old, creased, some sections torn. She tries to read it while driving.
#
# **MAYA**
# *(muttering)*
# Okay. Okay. Millhaven should be...
#
# Lightning flashes. In that brief white light, she sees something in the road ahead.
#
# A FIGURE.
#
# Standing perfectly still. Center of the lane.
#
# Maya SLAMS the brakes. The car fishtails. Tires scream. The duffel bag flies off the seat.
#
# The car stops.
#
# Silence.
#
# She stares through the windshield. The headlights illuminate an empty road.
#
# Nothing there.
#
# Maya sits frozen, breathing hard. She looks in the rearview mirror.
#
# Empty road behind her too.
#
# She slowly unclenches her hands from the wheel. Looks at them — they're shaking.
#
# **MAYA (CONT'D)**
# *(to herself)*
# You need sleep.
#
# She picks up the duffel bag from the floor. Something has spilled out — a PHOTOGRAPH. She picks it up.
#
# We see it briefly: a FARMHOUSE, white paint peeling, a red barn behind it. Written on the back in faded ink: *"Come home. — Dad."*
#
# Maya stares at it for a long moment.
#
# She puts the car back in drive.
#
# ---
#
# **EXT. MILLHAVEN - MAIN STREET - NIGHT**
#
# A small town that time forgot. Population sign reads: **MILLHAVEN — POP. 1,140.** Someone has spray-painted a question mark after the number.
#
# Maya drives slowly down the main strip. A diner. A hardware store. A church with a broken steeple. Most windows are dark.
#
# One light is on: **PATSY'S ALL-NIGHT DINER.**
#
# Maya pulls over.
#
# ---
#
# **INT. PATSY'S DINER - CONTINUOUS**
#
# Fluorescent lights hum. Vinyl booths. A pie case with two sad slices rotating slowly. Country music plays low from a radio behind the counter.
#
# PATSY (60s, big hair, kind face, moves like she's seen everything twice) wipes down the counter. She's the only one working.
#
# The only customer is an OLD MAN in a booth near the window, staring into a coffee cup like it owes him money.
#
# A bell jingles as Maya enters. Both Patsy and the old man look up.
#
# **PATSY**
# Sit anywhere, hon.
#
# Maya slides into a stool at the counter. She sets the photograph face-down on the formica.
#
# **PATSY (CONT'D)**
# Coffee?
#
# **MAYA**
# Please. And whatever's hot.
#
# **PATSY**
# Soup's hot. Pie's... room temperature.
#
# **MAYA**
# Soup's fine.
#
# Patsy pours the coffee. Studies Maya with the practiced eye of someone who's fed a thousand strangers.
#
# **PATSY**
# You look like you drove a long way.
#
# **MAYA**
# Fourteen hours.
#
# **PATSY**
# From where?
#
# **MAYA**
# Seattle.
#
# Patsy sets a bowl of vegetable soup in front of her.
#
# **PATSY**
# What brings you to Millhaven?
#
# Maya wraps both hands around the coffee mug.

# %%
# High temperature - more creative  
messages = []
add_user_message(messages, user_prompt)

answer = chat(messages, temperature=1.0)
print("High temperature answer:", answer, sep="\n")
# Out:
# High temperature answer:
# # BETWEEN WORLDS
#
# ### An Original Screenplay
#
# ---
#
# FADE IN:
#
# ---
#
# ## ACT ONE
#
# ---
#
# **EXT. RURAL HIGHWAY - NIGHT**
#
# A two-lane road cuts through flat, empty farmland. No streetlights. Just darkness and stars.
#
# A pair of headlights appear in the distance. Moving fast.
#
# A beaten-up 1998 Honda Civic hums down the road. The passenger side mirror is held on with duct tape. A dream catcher hangs from the rearview mirror.
#
# **INT. HONDA CIVIC - CONTINUOUS**
#
# MARA CHEN (28, sharp eyes, paint-stained fingers, hasn't slept in two days) grips the steering wheel. A half-eaten gas station burrito sits in the cupholder. Her phone is propped against it, GPS running.
#
# A duffel bag and an old wooden box sit on the back seat.
#
# The radio plays static-laced country music she isn't really listening to.
#
# Her phone BUZZES. The screen reads: **DAD - CALLING.**
#
# She stares at it.
#
# It rings.
#
# It stops.
#
# She exhales.
#
# The GPS CHIMES.
#
# **GPS (V.O.)**
# In half a mile, turn left onto County Road 9.
#
# Mara squints through the windshield. There's nothing out there. Just flat dark earth and sky.
#
# **MARA**
# *(to herself)*
# There is absolutely nothing out there.
#
# She turns anyway.
#
# **EXT. COUNTY ROAD 9 - CONTINUOUS**
#
# The road becomes gravel. The car rattles. Trees begin to appear on either side, thin and white-barked, closing in like a corridor.
#
# Mara slows down.
#
# Ahead, in the headlights — a FIGURE standing at the side of the road.
#
# She pumps the brakes. The car stops.
#
# The figure is a man. ELIOT VOSS (30s, tall, wearing a jacket too light for the cold, a cut above his eyebrow dried brown). He raises one hand. Not waving exactly. More like acknowledging.
#
# Mara stares at him through the windshield.
#
# He stares back.
#
# A long beat.
#
# She rolls down the window.
#
# **MARA**
# You okay?
#
# **ELIOT**
# Probably not.
#
# **MARA**
# You need a ride?
#
# **ELIOT**
# Where are you going?
#
# **MARA**
# *(beat)*
# Millhaven.
#
# **ELIOT**
# *(quiet)*
# Yeah. I need a ride.
#
# She looks at him. Looks at the empty dark road behind him. Nothing back there. No car. No house. Nothing.
#
# She unlocks the door.
#
# He gets in.
#
# **INT. HONDA CIVIC - CONTINUOUS**
#
# Eliot closes the door. He holds a canvas backpack on his lap. He looks forward.
#
# Mara pulls back onto the road. She watches him from the corner of her eye.
#
# **MARA**
# Eliot.
#
# **ELIOT**
# *(without looking)*
# What?
#
# **MARA**
# That's what I was going to ask you. Your name.
#
# **ELIOT**
# Oh. Sorry. Eliot.
# *(beat)*
# Voss.
#
# **MARA**
# Mara.
#
# They ride in silence for a moment. The trees thin out again. Open fields return.
#
# **MARA (CONT'D)**
# What happened to your head?
#
# He touches the cut instinctively.
#
# **ELIOT**
# Car went off the road about two miles back. Hit a ditch.
#
# **MARA**
# You hit your head?
#
# **ELIOT**
# Windshield.
#
# **MARA**
# Do you need a hospital?
#
# **ELIOT**
# *(firmly)*
# No hospital.
#
# She glances at him.
#
# **MARA**
# Okay.
#
# Another silence.
#
# **ELIOT**
# What's in Millhaven?
#
# **MARA**
# *(pause)*
# My grandmother died.
#
# **ELIOT**
# I'm sorry.
#
# **MARA**
# Don't be. We weren't close.
# *(beat)*
# I mean — we were. Once.
# *(beat)*
# It's complicated.
#
# **ELIOT**
# Most things
